# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.listdir('/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/4.Tópicos Avançados de Machine Learning')
# Out:
# ['Musica.csv',
#  'insurance.csv',
#  'Churn_prever.csv',
#  'Churn_treino.csv',
#  'credit_simple.csv',
#  'ad.data',
#  'PCA.ipynb',
#  'SelecaoAtributos.ipynb',
#  'visual_assessment_of_tendency.py',
#  'metric.py',
#  'hopkins.py',
#  'Unbal.ipynb',
#  '1.1.Engenharia e Seleção de Atributos.pdf',
#  '1.8.Seleção de Atributos.pdf',
#  '2.1.Avaliando a variabilidade de um modelo.pdf',
#  '3.1.Avaliando desempenho de modelos.pdf',
#  '4.1.Custo.pdf',
#  '5.1.Técnicas Avançadas de Clusters.pdf',
#  '6.1.ClassificacacaoMultilabel.pdf',
#  '6.2.Metricas para Multilabel.pdf',
#  '7.1.datasets desbalanceados.pdf',
#  '8.1.AutoML e Tunning de Modelos.pdf',
#  '8.2.AutoML e Tunning de Modelos.pdf',
#  '1.6.PCA.pdf',
#  'BestCluster.ipynb',
#  'AutoMLH2O.ipynb',
#  'AutoML.ipynb',
#  'Multilabel.ipynb',
#  'Cluster.ipynb',
#  'EngAtributos.ipynb']

# %%
import pandas as pd

dataset = pd.read_csv(
    '/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/4.Tópicos Avançados de Machine Learning/credit_simple.csv',
    sep=';'
)

dataset.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO        DATA  \
# 0       1169.0                4     67           nenhum  01/01/2019
# 1       5951.0                2     22           nenhum  01/01/2020
# 2       2096.0                3     49           nenhum  02/01/2020
# 3       7882.0                4     45           nenhum  02/01/2019
# 4       4870.0                4     53           nenhum  03/01/2018
#
#           ESTADOCIVIL            PROPOSITO CLASSE
# 0  masculino solteiro             radio/tv    bom
# 1         fem div/cas             radio/tv   ruim
# 2  masculino solteiro             educação    bom
# 3  masculino solteiro  mobilia/equipamento    bom
# 4  masculino solteiro           carro novo   ruim

# %%
y = dataset['CLASSE']
X = dataset.iloc[:,:-1]

# %%
X.isnull().sum() #Esse comando verifica quantos valores faltando (NaN / nulos) existem em cada coluna do dataset.
# Out:
# SALDO_ATUAL         7
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
mediana = X['SALDO_ATUAL'].median()
mediana
# Out:
# 2323.0

# %%
X['SALDO_ATUAL'] = X['SALDO_ATUAL'].fillna(mediana)

X.isnull().sum()
# Out:
# SALDO_ATUAL         0
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
agrupado = X.groupby(['ESTADOCIVIL']).size() #serve para calcular a moda
agrupado
# Out:
# ESTADOCIVIL
# fem div/cas               308
# masculino casado/viuvo     92
# masculino div/sep          50
# masculino solteiro        542
# dtype: int64

# %%
X['ESTADOCIVIL'] = X['ESTADOCIVIL'].fillna('masculino solteiro')
X.isnull().sum()
# Out:
# SALDO_ATUAL         0
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         0
# PROPOSITO           0
# dtype: int64

# %%
X['ESTADOCIVIL'].mode()[0] #“pegue o primeiro valor da lista de modas”
# Out:
# 'masculino solteiro'

# %%
desv = X['SALDO_ATUAL'].std()
desv #X['SALDO_ATUAL'] → pega a coluna
     #.std() → calcula o desvio padrão (standard deviation)
     #desv → guarda o resultado
# Out:
# 685936688.9820064

# %%
X.loc[X['SALDO_ATUAL']>= 2 * desv, 'SALDO_ATUAL']
# Out:
# 127    2.541111e+09
# 160    2.154441e+10
# Name: SALDO_ATUAL, dtype: float64

# %%
mediana = X['SALDO_ATUAL'].median()
mediana
# Out:
# 2323.0

# %%
X.loc[X['SALDO_ATUAL']>= 2 * desv, 'SALDO_ATUAL'] = mediana
X.loc[X['SALDO_ATUAL']>= 2 * desv]
# Out:
# Empty DataFrame
# Columns: [SALDO_ATUAL, RESIDENCIADESDE, IDADE, OUTROSPLANOSPGTO, DATA, ESTADOCIVIL, PROPOSITO]
# Index: []

# %%
agrupado = X.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# Eletrodomésticos        12
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  12
# qualificação             9
# radio/tv               280
# dtype: int64

# %%
X.loc[X['PROPOSITO']=='Eletrodomésticos','PROPOSITO'] = 'outros'
X.loc[X['PROPOSITO']=='qualificação','PROPOSITO'] = 'outros'
agrupado = X.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  33
# radio/tv               280
# dtype: int64

# %%
X['DATA']
# Out:
# 0      01/01/2019
# 1      01/01/2020
# 2      02/01/2020
# 3      02/01/2019
# 4      03/01/2018
#           ...
# 995    29/06/2018
# 996    30/06/2018
# 997    03/07/2018
# 998    04/07/2019
# 999    05/07/2018
# Name: DATA, Length: 1000, dtype: object

# %%
X['DATA'] = pd.to_datetime(X['DATA'], format='%d/%m/%Y')

# %%
X['DATA']
# Out:
# 0     2019-01-01
# 1     2020-01-01
# 2     2020-01-02
# 3     2019-01-02
# 4     2018-01-03
#          ...
# 995   2018-06-29
# 996   2018-06-30
# 997   2018-07-03
# 998   2019-07-04
# 999   2018-07-05
# Name: DATA, Length: 1000, dtype: datetime64[ns]

# %%
X['ANO'] = X['DATA'].dt.year
X['MES'] = X['DATA'].dt.month
X['DIASEMANA'] = X['DATA'].dt.day_name()

# %%
X['DIASEMANA']
# Out:
# 0        Tuesday
# 1      Wednesday
# 2       Thursday
# 3      Wednesday
# 4      Wednesday
#          ...
# 995       Friday
# 996     Saturday
# 997      Tuesday
# 998     Thursday
# 999     Thursday
# Name: DIASEMANA, Length: 1000, dtype: object

# %%
X['ESTADOCIVIL'].unique() #visualiza o estado civil em array
# Out:
# array(['masculino solteiro', 'fem div/cas', 'masculino div/sep',
#        'masculino casado/viuvo'], dtype=object)

# %%
X['PROPOSITO'].unique()#visualiza o estado civil em array
# Out:
# array(['radio/tv', 'educação', 'mobilia/equipamento', 'carro novo',
#        'carro usado', 'negócios', 'outros', 'obras'], dtype=object)

# %%
X['DIASEMANA'].unique() #visualiza o estado civil em array
# Out:
# array(['Tuesday', 'Wednesday', 'Thursday', 'Saturday', 'Sunday', 'Monday',
#        'Friday'], dtype=object)

# %%
labelencoder1 = LabelEncoder()
X['ESTADOCIVIL'] = labelencoder1.fit_transform(X['ESTADOCIVIL'])
X['PROPOSITO'] = labelencoder1.fit_transform(X['PROPOSITO'])
X['DIASEMANA'] = labelencoder1.fit_transform(X['DIASEMANA'])

# %%
X.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0            3          7  2019    1          5
# 1            0          7  2020    1          6
# 2            3          2  2020    1          4
# 3            3          3  2019    1          6
# 4            3          0  2018    1          6

# %%
outros = X['OUTROSPLANOSPGTO'].unique()
outros
# Out:
# array(['nenhum', 'banco', 'stores'], dtype=object)

# %%
z = pd.get_dummies(X['OUTROSPLANOSPGTO'], prefix = 'OUTROS')

# %%
z
# Out:
#      OUTROS_banco  OUTROS_nenhum  OUTROS_stores
# 0           False           True          False
# 1           False           True          False
# 2           False           True          False
# 3           False           True          False
# 4           False           True          False
# ..            ...            ...            ...
# 995         False           True          False
# 996         False           True          False
# 997         False           True          False
# 998         False           True          False
# 999         False           True          False
#
# [1000 rows x 3 columns]

# %%
X
# Out:
#      SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0         1169.0                4     67           nenhum 2019-01-01
# 1         5951.0                2     22           nenhum 2020-01-01
# 2         2096.0                3     49           nenhum 2020-01-02
# 3         7882.0                4     45           nenhum 2019-01-02
# 4         4870.0                4     53           nenhum 2018-01-03
# ..           ...              ...    ...              ...        ...
# 995       1736.0                4     31           nenhum 2018-06-29
# 996       3857.0                4     40           nenhum 2018-06-30
# 997        804.0                4     38           nenhum 2018-07-03
# 998       1845.0                4     23           nenhum 2019-07-04
# 999       4576.0                4     27           nenhum 2018-07-05
#
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0              3          7  2019    1          5
# 1              0          7  2020    1          6
# 2              3          2  2020    1          4
# 3              3          3  2019    1          6
# 4              3          0  2018    1          6
# ..           ...        ...   ...  ...        ...
# 995            0          3  2018    6          0
# 996            2          1  2018    6          2
# 997            3          7  2018    7          5
# 998            3          7  2019    7          4
# 999            3          1  2018    7          4
#
# [1000 rows x 10 columns]

# %%
sc = StandardScaler()
m = sc.fit_transform(X.iloc[:,0:3])
m
# Out:
# array([[-0.74551643,  1.04698668,  1.6392759 ],
#        [ 0.95774038, -0.76597727, -0.74024139],
#        [-0.41533679,  0.14050471,  0.68746898],
#        ...,
#        [-0.87552244,  1.04698668,  0.1058092 ],
#        [-0.50473818,  1.04698668, -0.68736323],
#        [ 0.46799171,  1.04698668, -0.47585058]])

# %%
X = pd.concat([X,z,pd.DataFrame(m,columns=['SALDO_ATUAL_N','RESIDENCEADESDE_N','IDADE_N'])],axis=1)

# %%
X.head()
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_banco  OUTROS_nenhum  \
# 0            3          7  2019    1          5         False           True
# 1            0          7  2020    1          6         False           True
# 2            3          2  2020    1          4         False           True
# 3            3          3  2019    1          6         False           True
# 4            3          0  2018    1          6         False           True
#
#    OUTROS_stores  SALDO_ATUAL_N  RESIDENCEADESDE_N   IDADE_N
# 0          False      -0.745516           1.046987  1.639276
# 1          False       0.957740          -0.765977 -0.740241
# 2          False      -0.415337           0.140505  0.687469
# 3          False       1.645526           1.046987  0.475956
# 4          False       0.572709           1.046987  0.898982

# %%
X.drop(columns=['SALDO_ATUAL','RESIDENCIADESDE','IDADE','OUTROSPLANOSPGTO','DATA','OUTROS_banco'], inplace=True)

# %%
X
# Out:
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_nenhum  \
# 0              3          7  2019    1          5           True
# 1              0          7  2020    1          6           True
# 2              3          2  2020    1          4           True
# 3              3          3  2019    1          6           True
# 4              3          0  2018    1          6           True
# ..           ...        ...   ...  ...        ...            ...
# 995            0          3  2018    6          0           True
# 996            2          1  2018    6          2           True
# 997            3          7  2018    7          5           True
# 998            3          7  2019    7          4           True
# 999            3          1  2018    7          4           True
#
#      OUTROS_stores  SALDO_ATUAL_N  RESIDENCEADESDE_N   IDADE_N
# 0            False      -0.745516           1.046987  1.639276
# 1            False       0.957740          -0.765977 -0.740241
# 2            False      -0.415337           0.140505  0.687469
# 3            False       1.645526           1.046987  0.475956
# 4            False       0.572709           1.046987  0.898982
# ..             ...            ...                ...       ...
# 995          False      -0.543562           1.046987 -0.264338
# 996          False       0.211898           1.046987  0.211566
# 997          False      -0.875522           1.046987  0.105809
# 998          False      -0.504738           1.046987 -0.687363
# 999          False       0.467992           1.046987 -0.475851
#
# [1000 rows x 10 columns]
