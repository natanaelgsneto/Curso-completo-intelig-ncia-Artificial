# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

base = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/3.Algoritmos de Machine Learning/insurance.csv",
    keep_default_na=False
)
base.drop("Unnamed: 0", axis=1, inplace=True)

base.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current       None
# 2        False      Senior  UpperMiddle   Psychopath     Current       None
# 3        False  Adolescent       Middle       Normal       Older       None
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football      None      Economy      Normal  ...     City       True
# 2   Football      None  FamilySedan   Excellent  ...     City      False
# 3   EggShell      None      Economy      Normal  ...   Suburb      False
# ...

# %%
import pandas as pd

base = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/3.Algoritmos de Machine Learning/insurance.csv",
    keep_default_na=False
)
base.drop("Unnamed: 0", axis=1, inplace=True)

base.head()
# Out:
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current       None
# 2        False      Senior  UpperMiddle   Psychopath     Current       None
# 3        False  Adolescent       Middle       Normal       Older       None
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football      None      Economy      Normal  ...     City       True
# 2   Football      None  FamilySedan   Excellent  ...     City      False
# 3   EggShell      None      Economy      Normal  ...   Suburb      False
# 4   Football  Moderate      Economy        Poor  ...     City      False
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

base = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/3.Algoritmos de Machine Learning/insurance.csv",
    keep_default_na=False
)
base.drop("Unnamed: 0", axis=1, inplace=True)

base.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current       None
# 2        False      Senior  UpperMiddle   Psychopath     Current       None
# 3        False  Adolescent       Middle       Normal       Older       None
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football      None      Economy      Normal  ...     City       True
# 2   Football      None  FamilySedan   Excellent  ...     City      False
# 3   EggShell      None      Economy      Normal  ...   Suburb      False
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

base = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/3.Algoritmos de Machine Learning/insurance.csv",
    keep_default_na=False
)
base.drop("Unnamed: 0", axis=1, inplace=True)

base.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current       None
# 2        False      Senior  UpperMiddle   Psychopath     Current       None
# 3        False  Adolescent       Middle       Normal       Older       None
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football      None      Economy      Normal  ...     City       True
# 2   Football      None  FamilySedan   Excellent  ...     City      False
# 3   EggShell      None      Economy      Normal  ...   Suburb      False
# ...

# %%
y = base.iloc[:,7].values
X  = base.drop(base.columns[7], axis=1).values
X
# Out:
# array([[False, 'Adult', 'Prole', ..., False, 'Thousand', 'Many'],
#        [False, 'Senior', 'Prole', ..., True, 'Thousand', 'Zero'],
#        [False, 'Senior', 'UpperMiddle', ..., True, 'Thousand', 'One'],
#        ...,
#        [False, 'Senior', 'UpperMiddle', ..., True, 'Thousand', 'Zero'],
#        [False, 'Adult', 'Middle', ..., True, 'Thousand', 'Zero'],
#        [False, 'Adult', 'Middle', ..., True, 'Thousand', 'Zero']],
#       dtype=object)

# %%
labelencoder = LabelEncoder()
for i in range(X.shape[1]):
  if X[:,i].dtype == 'object':
    X[:,i] = labelencoder.fit_transform(X[:,i])

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X,y,test_size=0.3, random_state=12)

# %%
modelo = RandomForestClassifier(random_state=1,max_depth=20, max_leaf_nodes=12, n_estimators=500)
modelo.fit(X_treinamento,y_treinamento)
# Out:
# RandomForestClassifier(max_depth=20, max_leaf_nodes=12, n_estimators=500,
#                        random_state=1)

# %%
tree_index = 1
tree_to_visualize = modelo.estimators_[tree_index]
plt.figure(figsize=(20,20))
plot_tree(tree_to_visualize, filled=True, feature_names=base.columns[:-1], class_names=True, rounded=True)
plt.show()

# %%
previsoes = modelo.predict(X_teste)

# %%
previsoes
# Out:
# array(['Moderate', 'Mild', 'Severe', ..., 'None', 'Mild', 'None'],
#       dtype=object)

# %%
accuracy = accuracy_score(y_teste,previsoes)
precision = precision_score(y_teste, previsoes, average='weighted')
recall = recall_score(y_teste, previsoes, average='weighted')
f1 = f1_score(y_teste, previsoes, average='weighted')
print(f'Acurácia: {accuracy}, Precisão: {precision}, Recall: {recall}, F1: {f1}')
# Out:
# Acurácia: 0.9296666666666666, Precisão: 0.9264995089298133, Recall: 0.9296666666666666, F1: 0.9252184168338298

# %%
report = classification_report(y_teste, previsoes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         Mild       0.88      0.61      0.72       570
#     Moderate       0.76      0.69      0.72       488
#         None       0.96      1.00      0.98      4253
#       Severe       0.87      0.93      0.90       689
#
#     accuracy                           0.93      6000
#    macro avg       0.87      0.81      0.83      6000
# weighted avg       0.93      0.93      0.93      6000

# %%
previsoes = modelo.predict(X_teste)

# %%
previsoes
# Out:
# array(['Moderate', 'Mild', 'Severe', ..., 'None', 'Mild', 'None'],
#       dtype=object)

# %%
accuracy = accuracy_score(y_teste,previsoes)
precision = precision_score(y_teste, previsoes, average='weighted')
recall = recall_score(y_teste, previsoes, average='weighted')
f1 = f1_score(y_teste, previsoes, average='weighted')
print(f'Acurácia: {accuracy}, Precisão: {precision}, Recall: {recall}, F1: {f1}')
# Out:
# Acurácia: 0.9296666666666666, Precisão: 0.9264995089298133, Recall: 0.9296666666666666, F1: 0.9252184168338298

# %%
report = classification_report(y_teste, previsoes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         Mild       0.88      0.61      0.72       570
#     Moderate       0.76      0.69      0.72       488
#         None       0.96      1.00      0.98      4253
#       Severe       0.87      0.93      0.90       689
#
#     accuracy                           0.93      6000
#    macro avg       0.87      0.81      0.83      6000
# weighted avg       0.93      0.93      0.93      6000

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

print(os.listdir('/content/drive/MyDrive'))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os

print(os.listdir('/content/drive/MyDrive/Colab Notebooks'))
# Out:
# ['.ipynb_checkpoints', 'Teste.ipynb', 'Curso completo inteligencia artificial', 'RegressaoLinear.ipynb', 'Projeto ABC.ipynb', 'IA']

# %%
import os

print(os.listdir('/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial'))
# Out:
# ['3.Algoritmos de Machine Learning', '13.Lógica Difusa', '6.Machine Learning Explicável', '9.Agentes de IA', '8.LLMs e Inteligência Artificial generativa', '5.Redes Neurais, Deep Learning e Computer Vision', '7.Processamento de Linguagem Natura', '2.Fundamentos de Machine Learning', '4.Tópicos Avançados de Machine Learning', '14.Projeto Final', '10.Detecção de Anomalias', '12.Algoritmos de Busca e Otimização', '1.Introdução', '11.Algoritmos Genéticos']

# %%
# importa a biblioteca joblib
# usada para salvar e carregar modelos de machine learning
import joblib

# salva o modelo treinado em um arquivo .pkl
joblib.dump(

    # modelo treinado que será salvo
    modelo,

    # caminho onde o arquivo será armazenado no Google Drive
    "/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/3.Algoritmos de Machine Learning/RandonForest/random_forest.pkl"
)

# mensagem informando que o modelo foi salvo com sucesso
print("Modelo salvo com sucesso!")
# Out:
# Modelo salvo com sucesso!

# %%
import joblib

# carrega o modelo salvo
modelo_carregado = joblib.load(
    "/content/drive/MyDrive/Colab Notebooks/Curso completo inteligencia artificial/3.Algoritmos de Machine Learning/RandonForest/random_forest.pkl"
)

# mostra as configurações do modelo
print(modelo_carregado)
# Out:
# RandomForestClassifier(max_depth=20, max_leaf_nodes=12, n_estimators=500,
#                        random_state=1)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# pega uma árvore da floresta
arvore = modelo_carregado.estimators_[0]

# define tamanho da imagem
plt.figure(figsize=(20,20))

# desenha a árvore
plot_tree(
    arvore,
    filled=True,
    feature_names=base.columns[:-1],
    class_names=True,
    rounded=True
)

# mostra a imagem
plt.show()
